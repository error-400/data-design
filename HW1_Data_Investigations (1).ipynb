# %% [markdown]
# # Data-Investigations
# Kristiana Marcon
#
# #### Dataset: NYC Leading Causes of Death
#
# #### Source: NYC Open Data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
df = pd.read_csv('DATA/New_York_City_Leading_Causes_of_Death.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 7 columns):
# Year                       1094 non-null int64
# Leading Cause              1094 non-null object
# Sex                        1094 non-null object
# Race Ethnicity             1094 non-null object
# Deaths                     1094 non-null object
# Death Rate                 1094 non-null object
# Age Adjusted Death Rate    1094 non-null object
# dtypes: int64(1), object(6)
# memory usage: 59.9+ KB

# %%
df.head()
# Out:
#    Year                                      Leading Cause Sex  \
# 0  2010                 Assault (Homicide: Y87.1, X85-Y09)   M
# 1  2011  Mental and Behavioral Disorders due to Acciden...   M
# 2  2011     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 3  2008  Certain Conditions originating in the Perinata...   F
# 4  2014  Accidents Except Drug Posioning (V01-X39, X43,...   F
#
#           Race Ethnicity Deaths Death Rate Age Adjusted Death Rate
# 0     Black Non-Hispanic    299       35.1                    35.5
# 1     Not Stated/Unknown      5          .                       .
# 2     Black Non-Hispanic   1840      215.7                   268.3
# 3  Other Race/ Ethnicity      .          .                       .
# 4               Hispanic     64        5.1                     5.4

# %%
df[df['Race Ethnicity'] == 'Asian and Pacific Islander']
# Out:
#       Year                                      Leading Cause Sex  \
# 7     2009                                   All Other Causes   M
# 8     2013     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 23    2007       Chronic Lower Respiratory Diseases (J40-J47)   M
# 29    2009    Intentional Self-Harm (Suicide: X60-X84, Y87.0)   M
# 31    2008     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 34    2008    Intentional Self-Harm (Suicide: X60-X84, Y87.0)   M
# 48    2010  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 50    2012            Influenza (Flu) and Pneumonia (J09-J18)   M
# 56    2008       Chronic Lower Respiratory Diseases (J40-J47)   F
# 58    2010     Chronic Liver Disease and Cirrhosis (K70, K73)   M
# 84    2010  Essential Hypertension and Renal Diseases (I10...   F
# 89    2007    Intentional Self-Harm (Suicide: X60-X84, Y87.0)   M
# 92    2007            Influenza (Flu) and Pneumonia (J09-J18)   F
# ...

# %%
df[(df['Sex'] == 'F') | (df['Race Ethnicity'] == 'Asian and Pacific Islander')]
# why are there still some Male entries and races other than Asian/Pacific Islander showing up?
# Out:
#       Year                                      Leading Cause Sex  \
# 3     2008  Certain Conditions originating in the Perinata...   F
# 4     2014  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 7     2009                                   All Other Causes   M
# 8     2013     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 10    2012                               Septicemia (A40-A41)   F
# 12    2012  Essential Hypertension and Renal Diseases (I10...   F
# 13    2014                        Diabetes Mellitus (E10-E14)   F
# 14    2008            Influenza (Flu) and Pneumonia (J09-J18)   F
# 17    2014       Chronic Lower Respiratory Diseases (J40-J47)   F
# 20    2008  Human Immunodeficiency Virus Disease (HIV: B20...   F
# 21    2010              Malignant Neoplasms (Cancer: C00-C97)   F
# 23    2007       Chronic Lower Respiratory Diseases (J40-J47)   M
# 24    2011              Malignant Neoplasms (Cancer: C00-C97)   F
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Year                                      Leading Cause Sex  \
# 0     2010                 Assault (Homicide: Y87.1, X85-Y09)   M
# 1     2011  Mental and Behavioral Disorders due to Acciden...   M
# 2     2011     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 3     2008  Certain Conditions originating in the Perinata...   F
# 4     2014  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 5     2007    Intentional Self-Harm (Suicide: X60-X84, Y87.0)   M
# 6     2012  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 7     2009                                   All Other Causes   M
# 8     2013     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 9     2014  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 10    2012                               Septicemia (A40-A41)   F
# 11    2012  Certain Conditions originating in the Perinata...   M
# 12    2012  Essential Hypertension and Renal Diseases (I10...   F
# ...

# %%
df.groupby('Year').count()
# Out:
#       Leading Cause  Sex  Race Ethnicity  Deaths  Death Rate  \
# Year
# 2007            141  141             141     141         141
# 2008            136  136             136     136         136
# 2009            135  135             135     135         135
# 2010            138  138             138     138         138
# 2011            141  141             141     141         141
# 2012            134  134             134     134         134
# 2013            133  133             133     133         133
# 2014            136  136             136     136         136
#
#       Age Adjusted Death Rate
# Year
# 2007                      141
# 2008                      136
# 2009                      135
# 2010                      138
# 2011                      141
# 2012                      134
# 2013                      133
# 2014                      136

# %%
df.groupby('Sex').count()
# Out:
#      Year  Leading Cause  Race Ethnicity  Deaths  Death Rate  \
# Sex
# F     554            554             554     554         554
# M     540            540             540     540         540
#
#      Age Adjusted Death Rate
# Sex
# F                        554
# M                        540

# %%
df[['Sex', 'Race Ethnicity']].describe()
# Out:
#          Sex      Race Ethnicity
# count   1094                1094
# unique     2                   6
# top        F  Not Stated/Unknown
# freq     554                 200

# %%
df[['Leading Cause', 'Sex']].describe()
# Out:
#                                   Leading Cause   Sex
# count                                      1094  1094
# unique                                       26     2
# top     Influenza (Flu) and Pneumonia (J09-J18)     F
# freq                                         96   554

# %%
df.groupby('Sex')['Year'].mean().sort_values(ascending = False).plot(kind = 'bar', figsize = (12, 5), title = 'Which sex dies more', color = 'red')
plt.ylim(0, 3000)
# Out:
# (0, 3000)

# %%
df.groupby('Year')['Deaths'].count().nlargest(8).plot(kind = 'bar', color = 'red')

# %%
df[(df['Race Ethnicity'] == 'Black Non-Hispanic') | (df['Race Ethnicity'] == 'White Non-Hispanic')]
# Out:
#       Year                                      Leading Cause Sex  \
# 0     2010                 Assault (Homicide: Y87.1, X85-Y09)   M
# 2     2011     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 6     2012  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 12    2012  Essential Hypertension and Renal Diseases (I10...   F
# 16    2011     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 21    2010              Malignant Neoplasms (Cancer: C00-C97)   F
# 22    2009              Malignant Neoplasms (Cancer: C00-C97)   M
# 24    2011              Malignant Neoplasms (Cancer: C00-C97)   F
# 25    2009              Malignant Neoplasms (Cancer: C00-C97)   F
# 32    2011              Malignant Neoplasms (Cancer: C00-C97)   M
# 35    2011                        Diabetes Mellitus (E10-E14)   M
# 39    2012     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 43    2013                               Septicemia (A40-A41)   F
# ...

# %%
df.plot.scatter(x='Year',y='Deaths', c='Red', title='Deadly Years')
# is Deaths not a numeric value?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f77df3161838> in <module>()
# ----> 1 df.plot.scatter(x='Year',y='Deaths', c='Red', title='Deadly Years')
#
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# /anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...

# %% [markdown]
# #### Conclusions:
#
# The leading cause of death is influenza and pneumonia. Women die from it more frequently than men.
#
# There is no significant numerical difference between the amount of deaths between men and women.
#
# Most deaths occurred in 2007 and 2011.
